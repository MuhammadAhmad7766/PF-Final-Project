# %% [markdown]
# ### _**Data Creation**

# %%
import pandas as pd

# %%
df = pd.read_csv("apple_sales_2024_with_nulls.csv")
df
# Out:
#          State         Region  iPhone Sales (in million units)  \
# 0    Chongqing  Greater China                             7.46
# 1      Germany         Europe                             8.63
# 2           UK         Europe                             5.61
# 3     Shanghai  Greater China                             7.82
# 4     Thailand   Rest of Asia                            16.70
# ..         ...            ...                              ...
# 995     Mexico  Rest of World                            29.86
# 996      Texas  North America                            27.83
# 997    Germany         Europe                            25.47
# 998   Shenzhen  Greater China                            15.34
# 999   Shanghai  Greater China                            26.30
#
#      iPad Sales (in million units)  Mac Sales (in million units)  \
# 0                             6.75                          1.19
# 1                            14.06                          7.03
# ...

# %% [markdown]
# ### _**Data Exploration (Initial Analysis)**_

# %%
df.head()
# Out:
#        State         Region  iPhone Sales (in million units)  \
# 0  Chongqing  Greater China                             7.46
# 1    Germany         Europe                             8.63
# 2         UK         Europe                             5.61
# 3   Shanghai  Greater China                             7.82
# 4   Thailand   Rest of Asia                            16.70
#
#    iPad Sales (in million units)  Mac Sales (in million units)  \
# 0                           6.75                          1.19
# 1                          14.06                          7.03
# 2                            NaN                          8.78
# 3                           7.97                          9.78
# 4                            NaN                          6.46
#
#    Wearables (in million units)  Services Revenue (in billion $)
# 0                          5.88                            15.88
# 1                          7.42                            10.12
# ...

# %%
df.tail()
# Out:
#         State         Region  iPhone Sales (in million units)  \
# 995    Mexico  Rest of World                            29.86
# 996     Texas  North America                            27.83
# 997   Germany         Europe                            25.47
# 998  Shenzhen  Greater China                            15.34
# 999  Shanghai  Greater China                            26.30
#
#      iPad Sales (in million units)  Mac Sales (in million units)  \
# 995                          10.30                          7.40
# 996                          12.52                          8.89
# 997                            NaN                          7.90
# 998                            NaN                          8.24
# 999                           4.06                          3.41
#
#      Wearables (in million units)  Services Revenue (in billion $)
# 995                          9.60                            18.56
# ...

# %%
df.sample()
# Out:
#         State         Region  iPhone Sales (in million units)  \
# 396  Shenzhen  Greater China                            17.76
#
#      iPad Sales (in million units)  Mac Sales (in million units)  \
# 396                           6.89                          9.97
#
#      Wearables (in million units)  Services Revenue (in billion $)
# 396                          11.6                             8.75

# %%
df.shape
# Out:
# (1000, 7)

# %%
df.size
# Out:
# 7000

# %%
df.columns
# Out:
# Index(['State', 'Region', 'iPhone Sales (in million units)',
#        'iPad Sales (in million units)', 'Mac Sales (in million units)',
#        'Wearables (in million units)', 'Services Revenue (in billion $)'],
#       dtype='object')

# %%
#we can also add single column
df.Region
# Out:
# 0      Greater China
# 1             Europe
# 2             Europe
# 3      Greater China
# 4       Rest of Asia
#            ...
# 995    Rest of World
# 996    North America
# 997           Europe
# 998    Greater China
# 999    Greater China
# Name: Region, Length: 1000, dtype: object

# %%
df.dtypes
# Out:
# State                               object
# Region                              object
# iPhone Sales (in million units)    float64
# iPad Sales (in million units)      float64
# Mac Sales (in million units)       float64
# Wearables (in million units)       float64
# Services Revenue (in billion $)    float64
# dtype: object

# %%
# this function Make list by using commas
df.values
# Out:
# array([['Chongqing', 'Greater China', 7.46, ..., 1.19, 5.88, 15.88],
#        ['Germany', 'Europe', 8.63, ..., 7.03, 7.42, 10.12],
#        ['UK', 'Europe', 5.61, ..., 8.78, nan, 19.85],
#        ...,
#        ['Germany', 'Europe', 25.47, ..., 7.9, 6.9, 15.0],
#        ['Shenzhen', 'Greater China', 15.34, ..., 8.24, 8.78, 15.49],
#        ['Shanghai', 'Greater China', 26.3, ..., 3.41, 5.69, 14.29]],
#       dtype=object)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   State                            925 non-null    object
#  1   Region                           940 non-null    object
#  2   iPhone Sales (in million units)  939 non-null    float64
#  3   iPad Sales (in million units)    918 non-null    float64
#  4   Mac Sales (in million units)     925 non-null    float64
#  5   Wearables (in million units)     930 non-null    float64
#  6   Services Revenue (in billion $)  933 non-null    float64
# dtypes: float64(5), object(2)
# memory usage: 54.8+ KB

# %%
df.describe()
# Out:
#        iPhone Sales (in million units)  iPad Sales (in million units)  \
# count                       939.000000                     918.000000
# mean                         17.404345                       8.544608
# std                           7.210554                       3.745834
# min                           5.030000                       2.020000
# 25%                          11.345000                       5.300000
# 50%                          17.060000                       8.765000
# 75%                          23.690000                      11.727500
# max                          29.940000                      14.990000
#
#        Mac Sales (in million units)  Wearables (in million units)  \
# count                    925.000000                    930.000000
# mean                       5.556303                      6.917882
# std                        2.510960                      2.957643
# min                        1.010000                      2.000000
# ...

# %%
df.describe(include='all')
# Out:
#             State         Region  iPhone Sales (in million units)  \
# count         925            940                       939.000000
# unique         25              5                              NaN
# top     Hong Kong  Greater China                              NaN
# freq           47            210                              NaN
# mean          NaN            NaN                        17.404345
# std           NaN            NaN                         7.210554
# min           NaN            NaN                         5.030000
# 25%           NaN            NaN                        11.345000
# 50%           NaN            NaN                        17.060000
# 75%           NaN            NaN                        23.690000
# max           NaN            NaN                        29.940000
#
#         iPad Sales (in million units)  Mac Sales (in million units)  \
# count                      918.000000                    925.000000
# ...

# %%
df.isnull()
# Out:
#      State  Region  iPhone Sales (in million units)  \
# 0    False   False                            False
# 1    False   False                            False
# 2    False   False                            False
# 3    False   False                            False
# 4    False   False                            False
# ..     ...     ...                              ...
# 995  False   False                            False
# 996  False   False                            False
# 997  False   False                            False
# 998  False   False                            False
# 999  False   False                            False
#
#      iPad Sales (in million units)  Mac Sales (in million units)  \
# 0                            False                         False
# 1                            False                         False
# 2                             True                         False
# 3                            False                         False
# ...

# %%
df.isnull().sum()
# Out:
# State                              75
# Region                             60
# iPhone Sales (in million units)    61
# iPad Sales (in million units)      82
# Mac Sales (in million units)       75
# Wearables (in million units)       70
# Services Revenue (in billion $)    67
# dtype: int64

# %% [markdown]
# ### _**Data Cleaning**_

# %%
# it can also be used for rows
df. rename(columns={"iPhone Sales (in million units)":"iPhone Sales","iPad Sales (in million units)":"iPad Sales","Mac Sales (in million units)":"Mac Sales","Wearables (in million units)":"Wearables units"}, inplace=True)
df
# Out:
#          State         Region  iPhone Sales  iPad Sales  Mac Sales  \
# 0    Chongqing  Greater China          7.46        6.75       1.19
# 1      Germany         Europe          8.63       14.06       7.03
# 2           UK         Europe          5.61         NaN       8.78
# 3     Shanghai  Greater China          7.82        7.97       9.78
# 4     Thailand   Rest of Asia         16.70         NaN       6.46
# ..         ...            ...           ...         ...        ...
# 995     Mexico  Rest of World         29.86       10.30       7.40
# 996      Texas  North America         27.83       12.52       8.89
# 997    Germany         Europe         25.47         NaN       7.90
# 998   Shenzhen  Greater China         15.34         NaN       8.24
# 999   Shanghai  Greater China         26.30        4.06       3.41
#
#      Wearables units  Services Revenue (in billion $)
# 0               5.88                            15.88
# ...

# %%
df.dropna()
# Out:
#          State         Region  iPhone Sales  iPad Sales  Mac Sales  \
# 0    Chongqing  Greater China          7.46        6.75       1.19
# 1      Germany         Europe          8.63       14.06       7.03
# 3     Shanghai  Greater China          7.82        7.97       9.78
# 6           UK         Europe         25.47        7.41       7.18
# 9        Italy         Europe          9.06        9.14       8.99
# ..         ...            ...           ...         ...        ...
# 991   Illinois  North America          9.31        7.82       6.97
# 992    Beijing  Greater China          7.20       12.62       3.97
# 995     Mexico  Rest of World         29.86       10.30       7.40
# 996      Texas  North America         27.83       12.52       8.89
# 999   Shanghai  Greater China         26.30        4.06       3.41
#
#      Wearables units  Services Revenue (in billion $)
# 0               5.88                            15.88
# ...

# %%
df.fillna(10)
# Out:
#          State         Region  iPhone Sales  iPad Sales  Mac Sales  \
# 0    Chongqing  Greater China          7.46        6.75       1.19
# 1      Germany         Europe          8.63       14.06       7.03
# 2           UK         Europe          5.61       10.00       8.78
# 3     Shanghai  Greater China          7.82        7.97       9.78
# 4     Thailand   Rest of Asia         16.70       10.00       6.46
# ..         ...            ...           ...         ...        ...
# 995     Mexico  Rest of World         29.86       10.30       7.40
# 996      Texas  North America         27.83       12.52       8.89
# 997    Germany         Europe         25.47       10.00       7.90
# 998   Shenzhen  Greater China         15.34       10.00       8.24
# 999   Shanghai  Greater China         26.30        4.06       3.41
#
#      Wearables units  Services Revenue (in billion $)
# 0               5.88                            15.88
# ...

# %%
df['In.mean']=df['iPhone Sales'].fillna(df['iPhone Sales'].mean())
df['In.mean']
df
# Out:
#          State         Region  iPhone Sales  iPad Sales  Mac Sales  \
# 0    Chongqing  Greater China          7.46        6.75       1.19
# 1      Germany         Europe          8.63       14.06       7.03
# 2           UK         Europe          5.61         NaN       8.78
# 3     Shanghai  Greater China          7.82        7.97       9.78
# 4     Thailand   Rest of Asia         16.70         NaN       6.46
# ..         ...            ...           ...         ...        ...
# 995     Mexico  Rest of World         29.86       10.30       7.40
# 996      Texas  North America         27.83       12.52       8.89
# 997    Germany         Europe         25.47         NaN       7.90
# 998   Shenzhen  Greater China         15.34         NaN       8.24
# 999   Shanghai  Greater China         26.30        4.06       3.41
#
#      Wearables units  Services Revenue (in billion $)  In.mean
# 0               5.88                            15.88     7.46
# ...

# %%
df.drop(['In.mean'],axis=1,inplace=True)
df
# Out:
#          State         Region  iPhone Sales  iPad Sales  Mac Sales  \
# 0    Chongqing  Greater China          7.46        6.75       1.19
# 1      Germany         Europe          8.63       14.06       7.03
# 2           UK         Europe          5.61         NaN       8.78
# 3     Shanghai  Greater China          7.82        7.97       9.78
# 4     Thailand   Rest of Asia         16.70         NaN       6.46
# ..         ...            ...           ...         ...        ...
# 995     Mexico  Rest of World         29.86       10.30       7.40
# 996      Texas  North America         27.83       12.52       8.89
# 997    Germany         Europe         25.47         NaN       7.90
# 998   Shenzhen  Greater China         15.34         NaN       8.24
# 999   Shanghai  Greater China         26.30        4.06       3.41
#
#      Wearables units  Services Revenue (in billion $)
# 0               5.88                            15.88
# ...

# %%
# To drop columns
del df['Wearables units']
df
# Out:
#          State         Region  iPhone Sales  iPad Sales  Mac Sales  \
# 0    Chongqing  Greater China          7.46        6.75       1.19
# 1      Germany         Europe          8.63       14.06       7.03
# 2           UK         Europe          5.61         NaN       8.78
# 3     Shanghai  Greater China          7.82        7.97       9.78
# 4     Thailand   Rest of Asia         16.70         NaN       6.46
# ..         ...            ...           ...         ...        ...
# 995     Mexico  Rest of World         29.86       10.30       7.40
# 996      Texas  North America         27.83       12.52       8.89
# 997    Germany         Europe         25.47         NaN       7.90
# 998   Shenzhen  Greater China         15.34         NaN       8.24
# 999   Shanghai  Greater China         26.30        4.06       3.41
#
#      Services Revenue (in billion $)
# 0                              15.88
# 1                              10.12
# 2                              19.85
# ...

# %%
# To drop rows
df = df.drop(4)
df
# Out:
#          State         Region  iPhone Sales  iPad Sales  Mac Sales  \
# 0    Chongqing  Greater China          7.46        6.75       1.19
# 1      Germany         Europe          8.63       14.06       7.03
# 2           UK         Europe          5.61         NaN       8.78
# 3     Shanghai  Greater China          7.82        7.97       9.78
# 5    Chongqing  Greater China           NaN       10.97       9.38
# ..         ...            ...           ...         ...        ...
# 995     Mexico  Rest of World         29.86       10.30       7.40
# 996      Texas  North America         27.83       12.52       8.89
# 997    Germany         Europe         25.47         NaN       7.90
# 998   Shenzhen  Greater China         15.34         NaN       8.24
# 999   Shanghai  Greater China         26.30        4.06       3.41
#
#      Services Revenue (in billion $)
# 0                              15.88
# 1                              10.12
# 2                              19.85
# ...

# %% [markdown]
# ### _**Data Manipulation**_

# %%
df.insert(5, "Average Sales ", 7)
df
# Out:
#          State         Region  iPhone Sales  iPad Sales  Mac Sales  \
# 0    Chongqing  Greater China          7.46        6.75       1.19
# 1      Germany         Europe          8.63       14.06       7.03
# 2           UK         Europe          5.61         NaN       8.78
# 3     Shanghai  Greater China          7.82        7.97       9.78
# 5    Chongqing  Greater China           NaN       10.97       9.38
# ..         ...            ...           ...         ...        ...
# 995     Mexico  Rest of World         29.86       10.30       7.40
# 996      Texas  North America         27.83       12.52       8.89
# 997    Germany         Europe         25.47         NaN       7.90
# 998   Shenzhen  Greater China         15.34         NaN       8.24
# 999   Shanghai  Greater China         26.30        4.06       3.41
#
#      Average Sales   Services Revenue (in billion $)
# 0                 7                            15.88
# 1                 7                            10.12
# ...

# %%
#Contatenation
df['iPhone and iPad']=df["iPhone Sales"]+df["iPad Sales"]
df['iPhone and iPad']
# Out:
# 0      14.21
# 1      22.69
# 2        NaN
# 3      15.79
# 5        NaN
#        ...
# 995    40.16
# 996    40.35
# 997      NaN
# 998      NaN
# 999    30.36
# Name: iPhone and iPad, Length: 999, dtype: float64

# %% [markdown]
# ### _**Data Selection**_

# %%
# To add rows
df.loc[3]=["Pakistan", "Punjab", 1.0, 5, 6, 5, 1.0, 1.0,]
df
# Out:
#          State         Region  iPhone Sales  iPad Sales  Mac Sales  \
# 0    Chongqing  Greater China          7.46        6.75       1.19
# 1      Germany         Europe          8.63       14.06       7.03
# 2           UK         Europe          5.61         NaN       8.78
# 3     Pakistan         Punjab          1.00        5.00       6.00
# 5    Chongqing  Greater China           NaN       10.97       9.38
# ..         ...            ...           ...         ...        ...
# 995     Mexico  Rest of World         29.86       10.30       7.40
# 996      Texas  North America         27.83       12.52       8.89
# 997    Germany         Europe         25.47         NaN       7.90
# 998   Shenzhen  Greater China         15.34         NaN       8.24
# 999   Shanghai  Greater China         26.30        4.06       3.41
#
#      Average Sales   Services Revenue (in billion $)  iPhone and iPad
# 0                 7                            15.88            14.21
# ...

# %%
df.loc[5]
# Out:
# State                                  Chongqing
# Region                             Greater China
# iPhone Sales                                 NaN
# iPad Sales                                 10.97
# Mac Sales                                   9.38
# Average Sales                                  7
# Services Revenue (in billion $)             12.7
# iPhone and iPad                              NaN
# Name: 5, dtype: object

# %%
df.loc[567, ["iPhone Sales", "iPad Sales"]]
# Out:
# iPhone Sales    25.58
# iPad Sales      11.99
# Name: 567, dtype: object

# %%
df.iloc[3]
# Out:
# State                              Pakistan
# Region                               Punjab
# iPhone Sales                            1.0
# iPad Sales                              5.0
# Mac Sales                               6.0
# Average Sales                             5
# Services Revenue (in billion $)         1.0
# iPhone and iPad                         1.0
# Name: 3, dtype: object

# %%
df.iloc[[3,4]]
# Out:
#        State         Region  iPhone Sales  iPad Sales  Mac Sales  \
# 3   Pakistan         Punjab           1.0        5.00       6.00
# 5  Chongqing  Greater China           NaN       10.97       9.38
#
#    Average Sales   Services Revenue (in billion $)  iPhone and iPad
# 3               5                              1.0              1.0
# 5               7                             12.7              NaN

# %%
df.iloc[[3,4],7]
# Out:
# 3    1.0
# 5    NaN
# Name: iPhone and iPad, dtype: float64

# %% [markdown]
# ### _**Statistical Analysis**_

# %%
df["iPhone Sales"].mean()
# Out:
# 17.397825159914714

# %%
df["iPhone Sales"].median()
# Out:
# 17.08

# %%
df["iPhone Sales"].mode
# Out:
# <bound method Series.mode of 0       7.46
# 1       8.63
# 2       5.61
# 3       1.00
# 5        NaN
#        ...
# 995    29.86
# 996    27.83
# 997    25.47
# 998    15.34
# 999    26.30
# Name: iPhone Sales, Length: 999, dtype: float64>

# %%
df["iPhone Sales"].min()
# Out:
# 1.0

# %%
df["iPhone Sales"].max()
# Out:
# 29.94

# %%
df["iPhone Sales"].std()
# Out:
# 7.227459300735264

# %% [markdown]
# ### _**Handle Duplicates**_

# %%
df.duplicated
# Out:
# <bound method DataFrame.duplicated of          State         Region  iPhone Sales  iPad Sales  Mac Sales  \
# 0    Chongqing  Greater China          7.46        6.75       1.19
# 1      Germany         Europe          8.63       14.06       7.03
# 2           UK         Europe          5.61         NaN       8.78
# 3     Pakistan         Punjab          1.00        5.00       6.00
# 5    Chongqing  Greater China           NaN       10.97       9.38
# ..         ...            ...           ...         ...        ...
# 995     Mexico  Rest of World         29.86       10.30       7.40
# 996      Texas  North America         27.83       12.52       8.89
# 997    Germany         Europe         25.47         NaN       7.90
# 998   Shenzhen  Greater China         15.34         NaN       8.24
# 999   Shanghai  Greater China         26.30        4.06       3.41
#
#      Average Sales   Services Revenue (in billion $)  iPhone and iPad
# ...

# %%
df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of          State         Region  iPhone Sales  iPad Sales  Mac Sales  \
# 0    Chongqing  Greater China          7.46        6.75       1.19
# 1      Germany         Europe          8.63       14.06       7.03
# 2           UK         Europe          5.61         NaN       8.78
# 3     Pakistan         Punjab          1.00        5.00       6.00
# 5    Chongqing  Greater China           NaN       10.97       9.38
# ..         ...            ...           ...         ...        ...
# 995     Mexico  Rest of World         29.86       10.30       7.40
# 996      Texas  North America         27.83       12.52       8.89
# 997    Germany         Europe         25.47         NaN       7.90
# 998   Shenzhen  Greater China         15.34         NaN       8.24
# 999   Shanghai  Greater China         26.30        4.06       3.41
#
#      Average Sales   Services Revenue (in billion $)  iPhone and iPad
# ...

# %%
df["iPad Sales"] = df["iPad Sales"].replace(5, 7)
df
# Out:
#          State         Region  iPhone Sales  iPad Sales  Mac Sales  \
# 0    Chongqing  Greater China          7.46        6.75       1.19
# 1      Germany         Europe          8.63       14.06       7.03
# 2           UK         Europe          5.61         NaN       8.78
# 3     Pakistan         Punjab          1.00        7.00       6.00
# 5    Chongqing  Greater China           NaN       10.97       9.38
# ..         ...            ...           ...         ...        ...
# 995     Mexico  Rest of World         29.86       10.30       7.40
# 996      Texas  North America         27.83       12.52       8.89
# 997    Germany         Europe         25.47         NaN       7.90
# 998   Shenzhen  Greater China         15.34         NaN       8.24
# 999   Shanghai  Greater China         26.30        4.06       3.41
#
#      Average Sales   Services Revenue (in billion $)  iPhone and iPad
# 0                 7                            15.88            14.21
# ...

# %% [markdown]
# ### _**Change Data Type**_

# %%
df["iPhone Sales"] = df["iPhone Sales"].astype(bool)
df.dtypes
# Out:
# State                               object
# Region                              object
# iPhone Sales                          bool
# iPad Sales                         float64
# Mac Sales                          float64
# Average Sales                        int64
# Services Revenue (in billion $)    float64
# iPhone and iPad                    float64
# dtype: object

# %% [markdown]
# ### _**Analyzing Data**_

# %%
df.groupby("iPhone Sales").describe()
# Out:
#              iPad Sales                                                  \
#                   count     mean       std   min    25%    50%      75%
# iPhone Sales
# True              918.0  8.54573  3.744651  2.02  5.335  8.765  11.7275
#
#                     Mac Sales            ... Services Revenue (in billion $)  \
#                 max     count      mean  ...                             75%
# iPhone Sales                             ...
# True          14.99     924.0  5.551234  ...                         16.2525
#
#                     iPhone and iPad                                          \
#                 max           count       mean       std  min    25%    50%
# iPhone Sales
# True          19.92           864.0  25.932928  8.384308  1.0  19.39  25.83
#
#
#                  75%    max
# iPhone Sales
# True          32.315  44.67
#
# [1 rows x 40 columns]

# %%
df.groupby('iPhone Sales')['iPad Sales'].sum()
# Out:
# iPhone Sales
# True    7844.98
# Name: iPad Sales, dtype: float64

# %%
df.sort_values(by='iPhone Sales', ascending=False)
# Out:
#          State         Region  iPhone Sales  iPad Sales  Mac Sales  \
# 0    Chongqing  Greater China          True        6.75       1.19
# 672    Florida  North America          True       11.35        NaN
# 659      Italy         Europe          True       11.82       2.63
# 660      Texas  North America          True        9.55       7.09
# 661     Canada  Rest of World          True        9.42       3.24
# ..         ...            ...           ...         ...        ...
# 339   New York  North America          True       14.06       6.39
# 340  Chongqing  Greater China          True        7.10       7.34
# 341      Japan   Rest of Asia          True       13.74       3.61
# 342   Illinois  North America          True        7.38        NaN
# 999   Shanghai  Greater China          True        4.06       3.41
#
#      Average Sales   Services Revenue (in billion $)  iPhone and iPad
# 0                 7                            15.88            14.21
# ...

# %%
df.filter(like='iPhone Sales', axis=1)
# Out:
#      iPhone Sales
# 0            True
# 1            True
# 2            True
# 3            True
# 5            True
# ..            ...
# 995          True
# 996          True
# 997          True
# 998          True
# 999          True
#
# [999 rows x 1 columns]

# %% [markdown]
# ### _**Visualization**_

# %%
df["Services Revenue (in billion $)"].value_counts().plot(kind="area")
# Out:
# <Axes: xlabel='Services Revenue (in billion $)'>

# %%
df["Region"].value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='Region'>

# %%
df["Region"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Region'>

# %%
df["Services Revenue (in billion $)"].value_counts().plot(kind="box")
# Out:
# <Axes: >

# %%
df["Services Revenue (in billion $)"].value_counts().plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
df["Services Revenue (in billion $)"].value_counts().plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["Region"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
df["Services Revenue (in billion $)"].value_counts().plot(kind="line")
# Out:
# <Axes: xlabel='Services Revenue (in billion $)'>

# %% [markdown]
# ### _**Final Export**_

# %%
df = pd.read_csv("apple_sales_2024_with_nulls.csv")
df
df.to_excel("pf new project.xlsx", sheet_name="secsheet")
